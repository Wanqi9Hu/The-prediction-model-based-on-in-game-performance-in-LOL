# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import pycaret

# %%
data=pd.read_csv('temp.csv')
data
# Out:
#         win  first  second  third  fourth  fifth      gameId  firstBlood  \
# 0         0     22      20     14      41     31  4247263043           1
# 1         1     30      32     23      16     45  4247263043           0
# 2         1     22      46     20      31     16  4247155821           0
# 3         0     33      13     41      14     31  4247155821           1
# 4         0     34      25     35      44     12  4241678498           0
# ...     ...    ...     ...    ...     ...    ...         ...         ...
# 137529    0     22      22     31      33     41  4170286047           0
# 137530    1     31      33     24      40     21  4130964458           1
# 137531    0     41      26     31      13     33  4130964458           0
# 137532    1     42      25     32      36     15  4119954410           0
# 137533    0     36      16     23      32     43  4119954410           1
#
#         firstTower  firstInhibitor  ...  firstDragon  firstRiftHerald  \
# ...

# %%
x1=pd.DataFrame(data,columns=['first','second','third','fourth','fifth','firstBlood'])
x2=pd.DataFrame(data,columns=['first','second','third','fourth','fifth','firstTower'])
x3=pd.DataFrame(data,columns=['first','second','third','fourth','fifth','firstBaron'])
x4=pd.DataFrame(data,columns=['first','second','third','fourth','fifth','firstDragon'])
x5=pd.DataFrame(data,columns=['first','second','third','fourth','fifth','firstRiftHerald'])

# %%
from pycaret.classification import *
clf = setup(data = x1, target ='firstBlood', train_size = 0.7)
# Out:
# <style type="text/css">
# #T_20c46_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_20c46_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20c46_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20c46_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_20c46_row0_col1" class="data row0 col1" >2649</td>
#     </tr>
#     <tr>
#       <th id="T_20c46_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_20c46_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_20c46_row1_col1" class="data row1 col1" >firstBlood</td>
#     </tr>
#     <tr>
#       <th id="T_20c46_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_68a3b_ th {
#   text-align: left;
# }
# ...

# %%
from pycaret.classification import *
clf = setup(data = x2, target ='firstTower', train_size = 0.7)
# Out:
# <style type="text/css">
# #T_89226_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_89226_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89226_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_89226_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_89226_row0_col1" class="data row0 col1" >5130</td>
#     </tr>
#     <tr>
#       <th id="T_89226_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_89226_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_89226_row1_col1" class="data row1 col1" >firstTower</td>
#     </tr>
#     <tr>
#       <th id="T_89226_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_6314c_ th {
#   text-align: left;
# }
# ...

# %%
from pycaret.classification import *
clf = setup(data = x3, target ='firstBaron', train_size = 0.7)
# Out:
# <style type="text/css">
# #T_839e9_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_839e9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_839e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_839e9_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_839e9_row0_col1" class="data row0 col1" >4737</td>
#     </tr>
#     <tr>
#       <th id="T_839e9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_839e9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_839e9_row1_col1" class="data row1 col1" >firstBaron</td>
#     </tr>
#     <tr>
#       <th id="T_839e9_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_9d2bc_ th {
#   text-align: left;
# }
# ...

# %%
from pycaret.classification import *
clf = setup(data = x4, target ='firstDragon', train_size = 0.7)
# Out:
# <style type="text/css">
# #T_52e2e_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_52e2e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52e2e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_52e2e_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_52e2e_row0_col1" class="data row0 col1" >5675</td>
#     </tr>
#     <tr>
#       <th id="T_52e2e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_52e2e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_52e2e_row1_col1" class="data row1 col1" >firstDragon</td>
#     </tr>
#     <tr>
#       <th id="T_52e2e_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_f52a1_ th {
#   text-align: left;
# }
# ...

# %%
from pycaret.classification import *
clf = setup(data = x5, target = 'firstRiftHerald', train_size = 0.7)
# Out:
# <style type="text/css">
# #T_d8e2e_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d8e2e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8e2e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d8e2e_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_d8e2e_row0_col1" class="data row0 col1" >2546</td>
#     </tr>
#     <tr>
#       <th id="T_d8e2e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d8e2e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d8e2e_row1_col1" class="data row1 col1" >firstRiftHerald</td>
#     </tr>
#     <tr>
#       <th id="T_d8e2e_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_5bfca_ th {
#   text-align: left;
# }
# ...
